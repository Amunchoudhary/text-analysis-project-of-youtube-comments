# %%
import pandas as pd

# Replace 'your_file.xlsx' with the path to your Excel file.
file_path = ("D:\\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx")

# Read the Excel file into a pandas DataFrame.
df = pd.read_excel(file_path)

# Display the first 5 rows of the DataFrame to verify the import.
print(df.head(5))
# Out:
#                                              comment  commentsCount  \
# 0                      Mahindra Rubicon and defender            412
# 1  Mahindra should make big truck like SUVs man s...            412
# 2                                  Range rover sport            412
# 3               Na can't afford ye to expensive hoga            412
# 4                                          defender-            412
#
#    hasCreatorHeart                       pageUrl    publishedTimeText  \
# 0            False  https://youtu.be/qk_Vb8ZFQMI            1 day ago
# 1            False  https://youtu.be/qk_Vb8ZFQMI            1 day ago
# 2            False  https://youtu.be/qk_Vb8ZFQMI           2 days ago
# 3            False  https://youtu.be/qk_Vb8ZFQMI           2 days ago
# 4            False  https://youtu.be/qk_Vb8ZFQMI  2 days ago (edited)
#
#    replyCount replyToCid                                              title  \
# 0           0        NaN  Upcoming Mahindra SUVs & its Platform Unveiled...
# 1           0        NaN  Upcoming Mahindra SUVs & its Platform Unveiled...
# 2           0        NaN  Upcoming Mahindra SUVs & its Platform Unveiled...
# 3           0        NaN  Upcoming Mahindra SUVs & its Platform Unveiled...
# 4           0        NaN  Upcoming Mahindra SUVs & its Platform Unveiled...
#
#       type      videoId  voteCount
# 0  comment  qk_Vb8ZFQMI          0
# 1  comment  qk_Vb8ZFQMI          0
# 2  comment  qk_Vb8ZFQMI          0
# 3  comment  qk_Vb8ZFQMI          0
# 4  comment  qk_Vb8ZFQMI          0

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Run these lines once to download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Assuming 'df' is your dataframe and 'text' is the colomn you're working with

# 1. Remove missing rows
df_processed = df.dropna(subset=['comment']).copy()

# 2. Tokenize it
df_processed['comment_tokenized'] = df_processed['comment'].apply(lambda x: word_tokenize(str(x)))

# 3. Make every text lowercase
df_processed['comment_lower'] = df_processed['comment'].str.lower()

# 4. Remove special characters
df_processed['comment_no_special_chars'] = df_processed['comment_lower'].apply(lambda x: re.sub(r'[^A-Za-z0-9\s]+', '', x))

# 5. Remove stopwords
stop_words = set(stopwords.words('english'))
df_processed['comment_tokenized_no_special'] = df_processed['comment_no_special_chars'].apply(lambda x: word_tokenize(x))
df_processed['comment_no_stopwords'] = df_processed['comment_tokenized_no_special'].apply(lambda x: [word for word in x if word not in stop_words])

# Display the head of the DataFrame with the new columns
print(df_processed[['comment', 'comment_tokenized', 'comment_lower', 'comment_no_special_chars', 'comment_no_stopwords']].head())
print(df.head())
# Out:
#                                              comment  \
# 0                      Mahindra Rubicon and defender
# 1  Mahindra should make big truck like SUVs man s...
# 2                                  Range rover sport
# 3               Na can't afford ye to expensive hoga
# 4                                          defender-
#
#                                    comment_tokenized  \
# 0                 [Mahindra, Rubicon, and, defender]
# 1  [Mahindra, should, make, big, truck, like, SUV...
# 2                              [Range, rover, sport]
# 3     [Na, ca, n't, afford, ye, to, expensive, hoga]
# 4                                        [defender-]
#
#                                        comment_lower  \
# 0                      mahindra rubicon and defender
# 1  mahindra should make big truck like suvs man s...
# 2                                  range rover sport
# 3               na can't afford ye to expensive hoga
# 4                                          defender-
#
#                             comment_no_special_chars  \
# 0                      mahindra rubicon and defender
# 1  mahindra should make big truck like suvs man s...
# 2                                  range rover sport
# 3                na cant afford ye to expensive hoga
# 4                                           defender
#
#                                 comment_no_stopwords
# 0                      [mahindra, rubicon, defender]
# 1  [mahindra, make, big, truck, like, suvs, man, ...
# 2                              [range, rover, sport]
# 3            [na, cant, afford, ye, expensive, hoga]
# 4                                         [defender]
#                                              comment  commentsCount  \
# 0                      Mahindra Rubicon and defender            412
# 1  Mahindra should make big truck like SUVs man s...            412
# 2                                  Range rover sport            412
# 3               Na can't afford ye to expensive hoga            412
# 4                                          defender-            412
#
#    hasCreatorHeart                       pageUrl    publishedTimeText  \
# 0            False  https://youtu.be/qk_Vb8ZFQMI            1 day ago
# 1            False  https://youtu.be/qk_Vb8ZFQMI            1 day ago
# 2            False  https://youtu.be/qk_Vb8ZFQMI           2 days ago
# 3            False  https://youtu.be/qk_Vb8ZFQMI           2 days ago
# 4            False  https://youtu.be/qk_Vb8ZFQMI  2 days ago (edited)
#
#    replyCount replyToCid                                              title  \
# 0           0        NaN  Upcoming Mahindra SUVs & its Platform Unveiled...
# 1           0        NaN  Upcoming Mahindra SUVs & its Platform Unveiled...
# 2           0        NaN  Upcoming Mahindra SUVs & its Platform Unveiled...
# 3           0        NaN  Upcoming Mahindra SUVs & its Platform Unveiled...
# 4           0        NaN  Upcoming Mahindra SUVs & its Platform Unveiled...
#
#       type      videoId  voteCount
# 0  comment  qk_Vb8ZFQMI          0
# 1  comment  qk_Vb8ZFQMI          0
# 2  comment  qk_Vb8ZFQMI          0
# 3  comment  qk_Vb8ZFQMI          0
# 4  comment  qk_Vb8ZFQMI          0
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\choud\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\choud\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Define the name for the new Excel file
output_file_path = 'D:\\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx'

# Save the processed DataFrame to a new Excel file.
# index=False ensures that the pandas index is not saved as a separate column.
df_processed.to_excel(output_file_path, index=False)

print(f"Successfully saved the updated DataFrame to {output_file_path}")
# Out:
# Successfully saved the updated DataFrame to D:\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx

# %%
pip install textblob
# Out:
# Collecting textblob
#   Using cached textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: nltk>=3.9 in c:\users\choud\anaconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\choud\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in c:\users\choud\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\choud\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\choud\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\choud\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Using cached textblob-0.19.0-py3-none-any.whl (624 kB)
# Installing collected packages: textblob
# Successfully installed textblob-0.19.0

# %%
from textblob import TextBlob

# --- Step 1: Load the preprocessed Excel file ---
preprocessed_file = 'D:\\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx'
df = pd.read_excel(preprocessed_file)

# TextBlob works on strings, but the 'no_stopwords' column is a list of words.
# We need to convert it back to a string first.
# Example: ['first', 'text', 'great'] -> "first text great"
# The .apply() method with a lambda function is perfect for this.
df['cleaned_comment_for_sentiment'] = df['comment_no_stopwords'].apply(lambda tokens: ' '.join(eval(tokens)) if isinstance(tokens, str) else ' '.join(tokens))


# --- Step 2: Perform Sentiment Analysis ---

# Function to calculate polarity (sentiment score)
def get_sentiment_score(text):
  return TextBlob(text).sentiment.polarity

# Function to categorize sentiment based on polarity
def get_sentiment_category(score):
  if score > 0:
    return 'Positive'
  elif score < 0:
    return 'Negative'
  else:
    return 'Neutral'

# Create the 'sentiment_score' column by applying the function
df['sentiment_score'] = df['cleaned_comment_for_sentiment'].apply(get_sentiment_score)

# Create the 'sentiment_category' column by applying the function
df['sentiment_category'] = df['sentiment_score'].apply(get_sentiment_category)


# --- Step 3: Display the results and save to a new Excel file ---

print("DataFrame with Sentiment Analysis results:")
# Display all columns to verify the result
print(df[['comment', 'cleaned_comment_for_sentiment', 'sentiment_score', 'sentiment_category']].to_string())

# Define the name for the final output file
output_filename = 'D:\\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx'

# Save the final DataFrame to the new Excel file
df.to_excel(output_filename, index=False)

print(f"\nSuccessfully saved the data with sentiment analysis to '{output_filename}'")
# Out:
# DataFrame with Sentiment Analysis results:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  comment                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   cleaned_comment_for_sentiment  sentiment_score sentiment_category
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Mahindra Rubicon and defender                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       mahindra rubicon defender         0.000000            Neutral
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Mahindra should make big truck like SUVs man small suvs are not that appealing                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      mahindra make big truck like suvs man small suvs appealing         0.083333           Positive
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Range rover sport                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               range rover sport         0.000000            Neutral
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Na can't afford ye to expensive hoga                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                na cant afford ye expensive hoga        -0.500000           Negative
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              defender-                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        defender         0.000000            Neutral
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  bekar                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           bekar         0.000000            Neutral
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Vision x to sonet lag rhi hai puri ki puri ,xuv3xO khasiyat hai uski width1800+ par mujhe is main ye cheej to lag nahi rhi hai , engine to sab ko pata hai 1.2 ltr turbo, kuch khaas sa nahi laga ,vision s gaadi to same to same jimny lag rhi hai ye dono gaadiya ne bilkul niras kiya mahindra se ummed hoti hai thoda hatke par isne safe khela hai                                                                                                                                                                                                                                                                                                                                                                                                              vision x sonet lag rhi hai puri ki puri xuv3xo khasiyat hai uski width1800 par mujhe main ye cheej lag nahi rhi hai engine sab ko pata hai 12 ltr turbo kuch khaas sa nahi laga vision gaadi jimny lag rhi hai ye dono gaadiya ne bilkul niras kiya mahindra se ummed hoti hai thoda hatke par isne safe khela hai         0.333333           Positive
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Faisal bhai to dance hee krte hein gaadiyon ke paas camera leke❤\nEnding of this video                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       faisal bhai dance hee krte hein gaadiyon ke paas camera leke ending video         0.000000            Neutral
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Tata add                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        tata add         0.000000            Neutral
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Ye minecraft jyada khel rahi hai mahindra. All cars look like blocks.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ye minecraft jyada khel rahi hai mahindra cars look like blocks         0.000000            Neutral
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Bhai any remarks o mahindra thar safety. Seen some bad accidents and that vehicle doesn't look very safe                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   bhai remarks mahindra thar safety seen bad accidents vehicle doesnt look safe        -0.100000           Negative
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Video on tesla model Y                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               video tesla model         0.000000            Neutral
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Why Indian automakers are not betting on 2 seater/city rider cars.\n\nUnfortunately many Indians are waiting for nano/E2O type of cars. And foriegn companies are cashing this gap.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            indian automakers betting 2 seatercity rider cars unfortunately many indians waiting nanoe2o type cars foriegn companies cashing gap         0.500000           Positive
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     But India needs more of big suvs like fortuners and ford endeavour, but all Brands failed in that                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                india needs big suvs like fortuners ford endeavour brands failed        -0.250000           Negative
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Bhai m Jaipur se hu or kisi din milunga jrur jb ap gaadi ka shoot kr rhe hoge                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        bhai jaipur se hu kisi din milunga jrur jb ap gaadi ka shoot kr rhe hoge         0.000000            Neutral
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Hi Gagan, You asked me to wait for the new Brezza (face lift or whatever) till Aug 2025. Please बताओ कब तक इंतजार करें नई Brezza का या इससे पहले कि इसमें भी 3 सिलिन्डर इंजन आए, current 4 cylinder मॉडल खऱीद लें अगर इसको बंद करने वाले हैं कंपनी वाले?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              hi gagan asked wait new brezza face lift whatever till aug 2025 please brezza 3 current 4 cylinder         0.068182           Positive
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Why every video of mahindra new concept cars starts with harrier ev Ads                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     every video mahindra new concept cars starts harrier ev ads         0.136364           Positive
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1:08 ky jbrdst look h                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            108 ky jbrdst look h         0.000000            Neutral
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         2:36 first thing come to my mind Ford bronco.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           236 first thing come mind ford bronco         0.250000           Positive
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Sari gaadi fuddu h,,,ese lg rha h jese baccho ke khelne ke toy ho                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  sari gaadi fuddu hese lg rha h jese baccho ke khelne ke toy ho         0.000000            Neutral
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Kya ye sari ev hai sir??                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          kya ye sari ev hai sir         0.000000            Neutral
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Permium user  on add                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                permium user add         0.000000            Neutral
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Tata full on bakchodi ke mood me hai                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  tata full bakchodi ke mood hai         0.350000           Positive
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Looks like Mahindra is designing cars just for Gurgaon                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      looks like mahindra designing cars gurgaon         0.000000            Neutral
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Vision-T looks like Rubicon                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      visiont looks like rubicon         0.000000            Neutral
# ...
# 92                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Sab defender banane me lage he bna koi ni pa rha                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      sab defender banane lage bna koi ni pa rha         0.000000            Neutral
# 93                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Tata ad                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         tata ad         0.000000            Neutral
# 94                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Mahindra kisi ko car nhi bechne dega Tesla ko bhi India se bharna padega                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        mahindra kisi ko car nhi bechne dega tesla ko bhi india se bharna padega         0.000000            Neutral
# 95                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Iss video pe sirf harrier.ev ki ad hi kyu aa rhi hai Tata kya chahte hai                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         iss video pe sirf harrierev ki ad hi kyu aa rhi hai tata kya chahte hai         0.000000            Neutral
# 96                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Are kya bakwas bna diya inhone...main gaadi koi launch karo jisko khreed sake                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          kya bakwas bna diya inhonemain gaadi koi launch karo jisko khreed sake         0.000000            Neutral
# 97                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Upcoming ok\nWhat about Down Going ?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               upcoming ok going         0.500000           Positive
# 98                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           3xo jaisi h                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     3xo jaisi h         0.000000            Neutral
# 99                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Mujhe yeh bekar lagi                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            mujhe yeh bekar lagi         0.000000            Neutral
#
# Successfully saved the data with sentiment analysis to 'D:\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx'

# %%
import matplotlib.pyplot as plt

# --- Step 1: Load the data from the Excel file ---
file_to_plot = 'D:\\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx'
df = pd.read_excel(file_to_plot)

# --- Step 2: Count the values in the 'sentiment_category' column ---
# .value_counts() is a convenient pandas method that counts the occurrences of each unique item.
sentiment_counts = df['sentiment_category'].value_counts()

print("Counts of each sentiment category:")
print(sentiment_counts)
print("\n" + "="*50 + "\n")


# --- Step 3: Plot the pie chart ---

# Create the plot
plt.figure(figsize=(8, 8)) # Sets the figure size for better readability
plt.pie(sentiment_counts,
        labels=sentiment_counts.index,
        autopct='%1.1f%%', # Adds the percentage label to one decimal place
        startangle=140,      # Rotates the chart for better aesthetics
        colors=['#4CAF50', '#FFC107', '#F44336']) # Optional: custom colors (Green, Amber, Red)

# Add a title to the chart
plt.title('Distribution of Sentiment Categories', fontsize=16)

# Ensure the pie chart is a circle
plt.axis('equal')

# Display the chart
plt.show()
# Out:
# Counts of each sentiment category:
# sentiment_category
# Neutral     74
# Positive    19
# Negative     7
# Name: count, dtype: int64
#
# ==================================================

# %%
import ast
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# --- Step 1: Load the data and prepare the text column ---
file_path = 'D:\\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx'
df = pd.read_excel(file_path)

# Safely convert the string representation of lists in 'text_no_stopwords' back to actual lists
# We use a helper function with error handling
def safe_literal_eval(val):
    try:
        return ast.literal_eval(val)
    except (ValueError, SyntaxError):
        return [] # Return empty list if cell is empty or malformed

df['tokens'] = df['comment_no_stopwords'].apply(safe_literal_eval)

# The vectorizer needs sentences (strings), not lists of words.
# We join the tokens back into a single string for each document.
df['cleaned_comment'] = df['tokens'].apply(lambda tokens: ' '.join(tokens))


# --- Step 2: Vectorize the text using TF-IDF ---
# TF-IDF helps to highlight words that are more important to a document.
# We will ignore words that appear in less than 2 documents or in more than 95% of documents.
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')

# Fit and transform the text data to a document-term matrix
tfidf_matrix = vectorizer.fit_transform(df['cleaned_comment'])

# Get the feature names (the words)
feature_names = vectorizer.get_feature_names_out()


# --- Step 3: Apply NMF for Topic Modeling ---
num_topics = 5

# Create and fit the NMF model
nmf_model = NMF(n_components=num_topics,
                random_state=42,       # For reproducible results
                beta_loss='kullback-leibler',
                solver='mu',
                max_iter=1000,
                alpha_W=0.00005,
                alpha_H=0.00005,
                l1_ratio=.5)

nmf_model.fit(tfidf_matrix)


# --- Step 4: Display the Topics ---
def display_topics(model, feature_names, num_top_words):
    for topic_idx, topic in enumerate(model.components_):
        # Print the topic number
        print(f"Topic #{topic_idx + 1}:")
        # Print the top words for that topic
        top_words = [feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]
        print(" ".join(top_words))
        print("-" * 50)

# Define how many top words you want to see for each topic
num_top_words = 10

print("Discovered Topics using NMF:")
display_topics(nmf_model, feature_names, num_top_words)
# Out:
# Discovered Topics using NMF:
# Topic #1:
# tata mahindra ad car add going concepts pe rhe troll
# --------------------------------------------------
# Topic #2:
# hai ke nahi ye kya ki gaadi bekar sxt koi
# --------------------------------------------------
# Topic #3:
# mahindra defender vision design copy cars indian global rover waiting
# --------------------------------------------------
# Topic #4:
# like look looks cars car mahindra suvs doesnt make thar
# --------------------------------------------------
# Topic #5:
# video bhai faisal gagan aayegi 3xo hind kab hee new
# --------------------------------------------------

# %%
import matplotlib.pyplot as plt
import ast
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# --- Step 1: Setup - Load Data and Re-run NMF model ---
# This part ensures the model and data are loaded for the plotting step.
file_path = 'D:\\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx'
df = pd.read_excel(file_path)

# Safely convert the string representation of lists back to actual lists
def safe_literal_eval(val):
    try: return ast.literal_eval(val)
    except (ValueError, SyntaxError): return []

df['tokens'] = df['comment_no_stopwords'].apply(safe_literal_eval)
df['cleaned_comment'] = df['tokens'].apply(lambda tokens: ' '.join(tokens))

# Vectorize the text using TF-IDF
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['cleaned_comment'])
feature_names = vectorizer.get_feature_names_out()

# Apply NMF for Topic Modeling
num_topics = 5
nmf_model = NMF(n_components=num_topics, random_state=42, beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha_W=0.00005, alpha_H=0.00005, l1_ratio=.5)
nmf_model.fit(tfidf_matrix)


# --- Step 2: Create a Bar Chart for Each Topic ---

# Define how many top words you want to display in each chart
num_top_words = 10

# Loop through each topic in the NMF model's components
for topic_idx, topic in enumerate(nmf_model.components_):
    # Get the top N words and their weights for the current topic
    # `topic.argsort()` sorts the word indices by weight in ascending order
    # `[:-num_top_words - 1:-1]` slices the last N items and reverses them to get descending order
    top_word_indices = topic.argsort()[:-num_top_words - 1:-1]

    # Get the actual words and their corresponding weights
    top_words = [feature_names[i] for i in top_word_indices]
    top_weights = topic[top_word_indices]

    # --- Plotting the bar chart ---
    plt.figure(figsize=(10, 7)) # Set the figure size

    # Create a horizontal bar chart for better readability of word labels
    plt.barh(top_words, top_weights, color='skyblue')

    # Invert the y-axis to have the most important word at the top
    plt.gca().invert_yaxis()

    # Add a title and labels
    plt.title(f'Top {num_top_words} Words for Topic #{topic_idx + 1}', fontsize=16)
    plt.xlabel('Word Weight (Importance)', fontsize=12)
    plt.ylabel('Words', fontsize=12)

    # Ensure the layout is clean
    plt.tight_layout()

    # Display the plot for the current topic
    plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from wordcloud import WordCloud

# --- Step 1: Setup - Load Data and Re-run NMF model ---
# This part ensures the model and data are loaded for the plotting step.
file_path = 'D:\\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx'
df = pd.read_excel(file_path)

# Safely convert the string representation of lists back to actual lists
def safe_literal_eval(val):
    try: return ast.literal_eval(val)
    except (ValueError, SyntaxError): return []

df['tokens'] = df['comment_no_stopwords'].apply(safe_literal_eval)
df['cleaned_comment'] = df['tokens'].apply(lambda tokens: ' '.join(tokens))

# Vectorize the text using TF-IDF
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['cleaned_comment'])
feature_names = vectorizer.get_feature_names_out()

# Apply NMF for Topic Modeling
num_topics = 5
nmf_model = NMF(n_components=num_topics, random_state=42, beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha_W=0.00005, alpha_H=0.00005, l1_ratio=.5)
nmf_model.fit(tfidf_matrix)


# --- Step 2: Generate and Plot a Word Cloud for Each Topic ---

# Loop through each topic in the NMF model's components
for topic_idx, topic in enumerate(nmf_model.components_):
    # Create a dictionary of words and their weights for the current topic
    # This is needed for the word cloud generator
    topic_words = {feature_names[i]: topic[i] for i in topic.argsort()}

    # Create the WordCloud object with desired parameters
    wordcloud = WordCloud(width=800,
                          height=400,
                          background_color='white',
                          colormap='viridis').generate_from_frequencies(topic_words)

    # --- Plotting the Word Cloud ---
    plt.figure(figsize=(10, 7))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Word Cloud for Topic #{topic_idx + 1}', fontsize=16)
    plt.axis('off') # Hide the axes
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 3
#       1 from sklearn.feature_extraction.text import TfidfVectorizer
#       2 from sklearn.decomposition import NMF
# ----> 3 from wordcloud import WordCloud
#       5 # --- Step 1: Setup - Load Data and Re-run NMF model ---
#       6 # This part ensures the model and data are loaded for the plotting step.
#       7 file_path = 'D:\\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx'
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\choud\anaconda3\lib\site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in c:\users\choud\anaconda3\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\choud\anaconda3\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\choud\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\choud\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\choud\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\choud\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\choud\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\choud\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\choud\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\choud\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from wordcloud import WordCloud

# --- Step 1: Setup - Load Data and Re-run NMF model ---
# This part ensures the model and data are loaded for the plotting step.
file_path = 'D:\\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx'
df = pd.read_excel(file_path)

# Safely convert the string representation of lists back to actual lists
def safe_literal_eval(val):
    try: return ast.literal_eval(val)
    except (ValueError, SyntaxError): return []

df['tokens'] = df['comment_no_stopwords'].apply(safe_literal_eval)
df['cleaned_comment'] = df['tokens'].apply(lambda tokens: ' '.join(tokens))

# Vectorize the text using TF-IDF
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['cleaned_comment'])
feature_names = vectorizer.get_feature_names_out()

# Apply NMF for Topic Modeling
num_topics = 5
nmf_model = NMF(n_components=num_topics, random_state=42, beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha_W=0.00005, alpha_H=0.00005, l1_ratio=.5)
nmf_model.fit(tfidf_matrix)


# --- Step 2: Generate and Plot a Word Cloud for Each Topic ---

# Loop through each topic in the NMF model's components
for topic_idx, topic in enumerate(nmf_model.components_):
    # Create a dictionary of words and their weights for the current topic
    # This is needed for the word cloud generator
    topic_words = {feature_names[i]: topic[i] for i in topic.argsort()}

    # Create the WordCloud object with desired parameters
    wordcloud = WordCloud(width=800,
                          height=400,
                          background_color='white',
                          colormap='viridis').generate_from_frequencies(topic_words)

    # --- Plotting the Word Cloud ---
    plt.figure(figsize=(10, 7))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Word Cloud for Topic #{topic_idx + 1}', fontsize=16)
    plt.axis('off') # Hide the axes
    plt.show()

# %%
from nltk.collocations import BigramAssocMeasures, BigramCollocationFinder
from nltk.collocations import TrigramAssocMeasures, TrigramCollocationFinder
from collections import Counter
import ast # To safely evaluate string representations of lists

# Load the Excel file with the preprocessed text
file_path = 'D:\\dataset_youtube-comments-scraper_2025-08-23_09-08-44-872 (2).xlsx'
df_ngrams = pd.read_excel(file_path)

# --- Step 1: Create a single list of all words from the 'text_no_stopwords' column ---

# The column might contain string representations of lists, so we use ast.literal_eval for safe conversion.
# We then flatten the list of lists into a single list of words.
all_words = [word for sublist in df_ngrams['comment_no_stopwords'].apply(ast.literal_eval) for word in sublist]


# --- Step 2: Calculate Bigram Frequencies ---

# Create bigrams
bigrams = list(nltk.bigrams(all_words))

# Count the frequency of each bigram
bigram_counts = Counter(bigrams)

print("--- Top 20 Most Common Bigrams ---")
# .most_common(20) returns a list of (bigram, count) tuples
for bigram, count in bigram_counts.most_common(20):
    print(f"{' '.join(bigram)}: {count}")


# --- Step 3: Calculate Trigram Frequencies ---

# Create trigrams
trigrams = list(nltk.trigrams(all_words))

# Count the frequency of each trigram
trigram_counts = Counter(trigrams)

print("\n--- Top 20 Most Common Trigrams ---")
# .most_common(20) returns a list of (trigram, count) tuples
for trigram, count in trigram_counts.most_common(20):
    print(f"{' '.join(trigram)}: {count}")
# Out:
# --- Top 20 Most Common Bigrams ---
# rhi hai: 5
# faisal bhai: 3
# looks like: 3
# nahi hai: 3
# video pe: 3
# hai aur: 3
# vision x: 2
# lag rhi: 2
# rahi hai: 2
# hai mahindra: 2
# cars look: 2
# look like: 2
# kr rhe: 2
# concept cars: 2
# harrier ev: 2
# roading segment: 2
# gagan bhai: 2
# mahindra vision: 2
# hai kya: 2
# 3 door: 2
#
# --- Top 20 Most Common Trigrams ---
# lag rhi hai: 2
# rahi hai mahindra: 2
# ke spy shots: 2
# land rover defender: 2
# mahindra doesnt make: 2
# faisal bhai ki: 2
# non practical concept: 2
# mahindra rubicon defender: 1
# rubicon defender mahindra: 1
# defender mahindra make: 1
# mahindra make big: 1
# make big truck: 1
# big truck like: 1
# truck like suvs: 1
# like suvs man: 1
# suvs man small: 1
# man small suvs: 1
# small suvs appealing: 1
# suvs appealing range: 1
# appealing range rover: 1
